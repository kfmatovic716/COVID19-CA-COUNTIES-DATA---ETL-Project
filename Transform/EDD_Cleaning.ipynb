# %%
pwd
# Out:
# 'C:\\Users\\jabuk\\Documents\\USC_DataScience\\ETL Project\\main'

# %%
import csv
import pandas as pd
import numpy as np

# %%
with open("employment_dataset.csv","r") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')

# %%
# Create path to data files
edd_path = "employment_dataset.csv"

# Read the EDD data and the study results
edd_df = pd.read_csv(edd_path)
edd_df
# Out:
#        Unnamed: 0 area_type          area_name                     date  year  \
# 0               0    County     Alameda County  2021-01-01T00:00:00.000  2021
# 1               1    County      Alpine County  2021-01-01T00:00:00.000  2021
# 2               2    County      Amador County  2021-01-01T00:00:00.000  2021
# 3               3    County       Butte County  2021-01-01T00:00:00.000  2021
# 4               4    County   Calaveras County  2021-01-01T00:00:00.000  2021
# ...           ...       ...                ...                      ...   ...
# 25995       25995    County      Orange County  2004-06-01T00:00:00.000  2004
# 25996       25996    County      Placer County  2004-06-01T00:00:00.000  2004
# 25997       25997    County      Plumas County  2004-06-01T00:00:00.000  2004
# 25998       25998    County   Riverside County  2004-06-01T00:00:00.000  2004
# 25999       25999    County  Sacramento County  2004-06-01T00:00:00.000  2004
#
# ...

# %%
converted_date = []

for day in date:
    converted_date.append(
        datetime.datetime.fromtimestamp(int(day)).strftime('%m/%d/%Y'))

converted_date

# %%
# Recreate a new df with only from March 2020 to January 2021
year_edd_df = edd_df.loc[edd_df["year"]>=2020]
year_edd_df
# Out:
#        Unnamed: 0         area_type          area_name  \
# 0               0            County     Alameda County
# 1               1            County      Alpine County
# 2               2            County      Amador County
# 3               3            County       Butte County
# 4               4            County   Calaveras County
# ...           ...               ...                ...
# 13654       13654  Sub-County Place    Yountville town
# 13655       13655  Sub-County Place         Yreka city
# 13656       13656  Sub-County Place     Yuba City city
# 13657       13657  Sub-County Place       Yucaipa city
# 13658       13658  Sub-County Place  Yucca Valley town
#
#                           date  year    month seasonally_adjusted_y_n  \
# 0      2021-01-01T00:00:00.000  2021  January                       N
# 1      2021-01-01T00:00:00.000  2021  January                       N
# 2      2021-01-01T00:00:00.000  2021  January                       N
# ...

# %%
# Remove Jan 2020, Feb 2020

#year_edd_df.loc[["2020-01-01T00:00:00.000", "2020-02-01T00:00:00.000"],["date","unemployment"]]
jan = year_edd_df["date"]=="2020-01-01T00:00:00.000"
feb = year_edd_df["date"]=="2020-02-01T00:00:00.000"
combine_janfeb = jan & feb
filter_combine = year_edd_df.loc[combine, :]
# filter_combine
# year_edd_df.loc[combine,:]
# year_edd_df.loc[((Jan_2020 == True) & (Feb_2020 == True)), :]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-01-01T00:00:00.000'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-b94ade1f54fa> in <module>
# ...

# %%
# Find the types of rows for area_type, aree
edd_df["area_type"].unique()
# Out:
# array(['County', 'Metropolitan Area', 'State', 'Sub-County Place',
#        'Metro Division', 'MSA'], dtype=object)

# %% [markdown]
# employment_df

# %%
edd_df["area_name"].unique()
# Out:
# array(['Alameda County', 'Alpine County', 'Amador County', ...,
#        'Vallejo-Fairfield, CA MSA', 'Visalia-Porterville, CA MSA',
#        'Yuba City, CA MSA'], dtype=object)
